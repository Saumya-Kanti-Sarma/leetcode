# %% [markdown]
# # Question
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# I can be placed before V (5) and X (10) to make 4 and 9.
# X can be placed before L (50) and C (100) to make 40 and 90.
# C can be placed before D (500) and M (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.
#
#
#
# Example 1:
#
# Input: s = "III"
# Output: 3
# Explanation: III = 3.
# Example 2:
#
# Input: s = "LVIII"
# Output: 58
# Explanation: L = 50, V= 5, III = 3.
# Example 3:
#
# Input: s = "MCMXCIV"
# Output: 1994
# Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.

# %% [markdown]
# ### Attempt NO 01
# Each Roman character has a numeric value. So just store every symbol in a dictionary and keep adding them. Simple, Fast and good time complexity
# For example: III, VII, LX
# Read every character in a forloop.
# Find its value ds[character].
# Add it to the running total.

# %%
class Solution(object):
    def romanToInt(self, s):
        inp = str(s)
        ds = {
            "I":1,
            "V":5,
            "X":10,
            "L":50,
            "C":100,
            "D":500,
            "M":1000
        }
        sum = 0
        for char in inp:
            if ds[char]:
                sum += ds[char]
            else:
                print('wrong number')
                break
        return sum

# %% [markdown]
# ## Result After First Attempt
#
# **2047 / 3999 testcases passed**
#
# Failed at:
#
# ```text
# Input:
# "MCMXCIV"
#
# Output:
# 2216
#
# Expected:
# 1994
# ```
#
# The main issue is that I am only adding one after another number, but in reality, Roman numbers are not just addition.
#
# For example:
#
# ```text
# IV -> 1 - 5 = 4
# VI -> 5 + 1 = 6
# ```
#
# So I have to figure out something.

# %% [markdown]
# ## Attempt NO 02
#
# I figure out that Roman numbers are grouped in a pair of two characters.
#
# For character that is not in a pair of 2, I can add a padding at the beginning of the code and everything should work fine.
#
# For example:
#
# ```text
# XIV => OXIV
# ```
#
# Where:
#
# ```text
# O = 0
# ```
#
# Then I can add a logic to remove `O` while doing calculation.

# %%
class Solution(object):
    def romanToInt(self, s):
        inp = str(s)
        ds = {
            "O":0,
            "I":1,
            "V":5,
            "X":10,
            "L":50,
            "C":100,
            "D":500,
            "M":1000
        }
        if len(s) == 1:
            return ds[s]
        else:
            if len(s) %2 !=0:
                copy_s = "O"+s
                arr = [] # ['OX', 'IV']
                for i in range(0, len(copy_s), 2):
                    num = copy_s[i:i+2]
                    n1 = ds[num[0]]
                    n2 = ds[num[1]]
                    if n1 == 0:
                        arr.append(n2)
                    elif n2 > n1:
                        arr.append(n2-n1)
                    else:
                        arr.append(n1+n2)
                return sum(arr);
            else:
                arr = [] # ['20', '4']
                for i in range(0, len(s), 2):
                    num = s[i:i+2]
                    n1 = ds[num[0]]
                    n2 = ds[num[1]]
                    if n1 == 0:
                        arr.append(n2)
                    elif n2 > n1:
                        arr.append(n2-n1)
                    else:
                        arr.append(n1+n2)
                return sum(arr);

roman = Solution()

print(roman.romanToInt("XVII"))
print(roman.romanToInt("XIV"))

# %% [markdown]
# ## Result After First Attempt
# **3359 / 3999 testcases passed**
#
# `s ="MCDLXXVI"`
#
# *Use Testcase*
#
# ```
# Output: 1676
# Expected: 1476
# ```

# %% [markdown]
# # Attempt 03
# now this failed because my understanding of Roman Number lacked.
#
# Instead of padding extra 0 in front of number if it has odd numbers I must pair the numbers incase the left digit is smaller then the right one.
#
# ```
# "MMCDXXV"
# ["M","M","C","D","X","X","V"]
# sum = 0
# M >= M so sum += 1000 and remove M
# M >= C so sum += 2000 and remove M
# C !>=D so sum += 2000 + (500 - 100) = 2400 and remove C and D
# X >= X so sum += 2410 and remove X
# X >= V so sum += 2420 and remove X
# V is last number so sum = 2425
# return sum
# ```

# %%
class Solution(object):
    def romanToInt(self, s):
        ds = {
            "I": 1,
            "V": 5,
            "X": 10,
            "L": 50,
            "C": 100,
            "D": 500,
            "M": 1000
        }
        
        total_sum = 0
        i = 0
        while i < len(s):
            if i == len(s) - 1:
                total_sum += ds[s[i]]
                i += 1
            else:
                n1 = ds[s[i]]
                n2 = ds[s[i + 1]]
                
                if n1 < n2:
                    total_sum += (n2 - n1)
                    i += 2 
                else:
                    total_sum += n1
                    i += 1
        
        return total_sum
